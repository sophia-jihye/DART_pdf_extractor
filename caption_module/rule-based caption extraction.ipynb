# %% [markdown]
# ## Caption Detector Usage

# %% [markdown]
# ### 개요
#
# #### Input
# - 공시문서 원본 pdf 파일
# - 추출한 image/table/text pickle 파일
#
# #### Output
# - 이미지 파일: result 폴더에 페이지별로 png 파일로 저장
# - 텍스트: result 폴더에 result.json으로 저장
#
# #### png 파일의 bounding box
# - image: 노란색
# - table: 빨간색
# - caption: 보라색
#
# #### result.json 구성
# - result[p]['image']: 페이지 p에 있는 각 이미지의 캡션을 원소로 갖는 리스트 (하나의 이미지 = 리스트로 된 하나의 원소)
# - result[p]['table']: 페이지 p에 있는 각 표의 캡션을 원소로 갖는 리스트 (하나의 표 = 리스트로 된 하나의 원소)

# %% [markdown]
# ### 소요 시간
# #### resolution 200 기준
# - [삼성전자]사업보고서(2022.03.08) : 569 페이지 / 10분 2초
# - [KB금융][정정]사업보고서(2022.03.25) : 917페이지 / 20분 52초
# - [LG생활건강][정정]사업보고서(2022.05.16) : 309페이지 / 6분 4초
# - [SK하이닉스]사업보고서(2022.03.22) : 336 페이지 / 6분 35초
# - [삼성바이오로직스]사업보고서(2022.03.21) : 264 페이지 / 5분 31초
# - [엔씨소프트]사업보고서(2022.03.22) : 308 페이지 / 4분 39초
# - [현대중공업]사업보고서(2022.03.14) : 378 페이지 / 6분 54초
#
# #### resolution 400 기준
# - [삼성바이오로직스]사업보고서(2022.03.21) : 264 페이지 / 13분 2초
# - [엔씨소프트]사업보고서(2022.03.22) : 308 페이지 / 11분 10초
#
# #### resolution 800 기준
# - [엔씨소프트]사업보고서(2022.03.22) : 308 페이지 / 36분 38초

# %%
import pandas as pd
from util import *
from caption_extraction import *

# %%
# 예시
# [KB금융][정정]사업보고서(2022.03.25)
# [LG생활건강][정정]사업보고서(2022.05.16)
# [SK하이닉스]사업보고서(2022.03.22)
# [삼성바이오로직스]사업보고서(2022.03.21)
# [삼성전자]사업보고서(2022.03.08)
# [엔씨소프트]사업보고서(2022.03.22)
# [현대중공업]사업보고서(2022.03.14)

# 공시문서 이름 (.pdf는 제외)
filename = '[삼성전자]사업보고서(2022.03.08)'

# 공시문서 pdf 원본의 경로
path = f'data/{filename}/{filename}.pdf'
pages = get_pages(get_pdf(path))

# pdfplumber로 추출한 image, table, text 정보
corp_image = pd.read_pickle(f'data/{filename}/{filename}_image.pickle')
corp_table = pd.read_pickle(f'data/{filename}/{filename}_table.pickle')
corp_text = pd.read_pickle(f'data/{filename}/{filename}_text.pickle')

# %%
caption_detector(pages, corp_image, corp_table, corp_text, corp=filename, resolution=400)
# Out:
#   0%|          | 0/264 [00:00<?, ?it/s]
# (p.4) caption for image: ['【 대표이사 등의 확인 】']
# (p.5) caption for table: ['(단위 : 사)', "※상세 현황은 '상세표-1. 연결대상 종속회사 현황(상세)' 참조"]
# (p.5) caption for table: []
# (p.6) caption for table: []
# (p.6) caption for table: ['※ 제6-1, 6-2회 무보증 사모사채의 경우 신용등급은 평가계약상 미공시조건에 따라 기재 하지 않았습니다.']
# (p.7) caption for table: ['※ 상기 등급 중 AA부터 B등급까지는 +, - 부호를 부가하여 동일 등급내에서의 우열을 나타냅니다.']
# (p.7) caption for table: ['※ AA부터 B까지는 동일 등급내에서 세분하여 구분할 필요가 있는 경우에는 "＋" 또는 "－"의 기호를 부여할 수 있다. ※ 예비평정의 경우 당해 등급기호의 앞에 "P"를 부기한다.']
# (p.8) caption for table: []
# (p.8) caption for table: []
# (p.8) caption for table: ['※ 2020년 12월 16일 제10차 이사회에서 김태한 사내이사는 대표이사 직위를 사임하였으 며, 존림 사내이사가 대표이사로 신규 선임되었습니다.']
# (p.9) caption for table: []
# (p.9) caption for table: []
# (p.9) caption for table: []
# (p.10) caption for table: []
# (p.11) caption for table: []
# (p.11) caption for table: ['(단위 : 원, 주)']
# (p.12) caption for table: []
# (p.12) caption for table: ['(기준일 : 2021년 12월 31일 )', '(단위 : 주)']
# (p.12) caption for table: []
# (p.13) caption for table: ["※ 사업보고서에 첨부된 정관의 최근개정일은 '19.03.22일이며, '22.03.29일 개최 예정인 제11기 정기주주총회 안건 중 정관 변경안은 없습니다."]
# (p.15) caption for table: ['(단위 : 백만원)', '※ 한국채택국제회계기준에 따라 작성되었습니다.(연결 기준)']
# (p.15) caption for table: ['(단위 : 백만원)', '※ CDMO 산업은 일반적으로 고객사로부터 BOM(Bill of Material)에 속하는 원/부재료비 전액 및 Handling Fee를 환급받는 구조를 취하고 있습니다. ※ 한국채택국제회계기준에 따라 작성되었습니다.(연결 기준)']
# (p.16) caption for table: ['(단위 : 배치)']
# (p.16) caption for table: ['(단위: 백만원)', '주1) 에 따라 임대료를 전액 면제 받고 있음.']
# (p.16) caption for table: ['(단위: 백만원)']
# (p.17) caption for table: ['(단위 : 백만원)']
# (p.17) caption for table: ['(단위 : 백만원)']
# (p.17) caption for table: ['[수주업무 프로세스]']
# (p.18) caption for table: []
# (p.19) caption for table: ['주1) 상기 수주총액 및 수주잔고는 고객사 수요 증가 시 협의 후 추가로 증가할 수 있음 상기 수주총액 및 수주잔고는 생산에 실 투입된 원료 및 부자재에 대한 원재료 매출, 기술이전 및 품질분석등의 주2) 서비스에 대한 매출 등이 제외된 금액임']
# (p.19) caption for table: ['(단위: 천원)']
# (p.20) caption for table: ['(*) 당사가 보유하는 현금시재액은 제외하였습니다.']
# (p.21) caption for table: []
# (p.21) caption for table: []
# (p.22) caption for table: ['(*) 통화스왑이 체결된 외화차입금은 환위험에 노출되지 않은것으로 보아 제외하였습니다.']
# (p.22) caption for table: []
# (p.23) caption for table: []
# (p.23) caption for table: []
# (p.24) caption for table: []
# (p.24) caption for table: ['(*) 해당 내용은 차입시점 기준으로 작성되었습니다.']
# (p.24) caption for table: []
# (p.24) caption for table: ['(단위: 원)']
# (p.25) caption for table: ['(단위: 백만USD)']
# (p.26) caption for table: ['[수행 업무]']
# (p.27) caption for table: ['(단위: 명)']
# (p.27) caption for table: ['[핵심 연구인력 현황]']
# (p.28) caption for table: []
# (p.28) caption for table: ['(단위: 천원, %)']
# (p.29) caption for table: ['주1) 한국채택국제회계기준에 따라 작성되었습니다.(연결 기준) 주2) 당사는 정부보조금 해당 사항 없습니다.']
# (p.29) caption for table: []
# (p.30) caption for table: []
# (p.31) caption for image: []
# (p.31) caption for table: []
# (p.31) caption for table: []
# (p.32) caption for table: ['※ 대상은 당사 제조사업장, 사내버스, 임차 건물 등입니다. ※ 상기 온실가스 배출량 및 에너지 사용량은 "국가온실가스종합관리시스템" 제출 자료입니다. ※ 배출량 및 에너지 사용량은 외부 검증기관 검증 결과 등에 따라 변동될 수 있습니다. ※ 녹색경영 관련 내용은 XI. 그 밖에 투자자 보호를 위하여 필요한 사항의 4. 작성기준일 이후 발생한 주요사항 등 기타사항 중 아. 녹색경영 부분을 참고하시기 바랍니다.']
# (p.33) caption for image: ['출처 : Evaluate Pharma 및 Mckinsey (2021년 4월)']
# (p.34) caption for image: ['출처 : Frost&Sullivan (2021년 7월)']
# (p.36) caption for table: ['(단위 : 백만원)']
# (p.37) caption for table: ['※ 제11기(당기)는 주주총회 승인전 연결재무제표입니다. 향후 제11기 정기주주총회에서 재무제표 승인 관련 안건이 부결되거나 수정이 발생한 경우 정정보고서를 통해 그 내용 및 사유 등을 반영할 예정입니다.']
# (p.37) caption for table: ['(단위 : 백만원)']
# (p.38) caption for table: ['※ 제11기(당기)는 주주총회 승인전 별도재무제표입니다. 향후 제11기 정기주주총회에서 재무제표 승인 관련 안건이 부결되거나 수정이 발생한 경우 정정보고서를 통해 그 내용 및 사유 등을 반영할 예정입니다.']
# (p.39) caption for table: []
# (p.40) caption for table: []
# (p.40) caption for table: ['(단위 : 원)']
# (p.41) caption for table: []
# (p.41) caption for table: ['(단위 : 원)']
# (p.42) caption for table: ['(단위 : 원)']
# (p.43) caption for table: []
# (p.43) caption for table: []
# (p.44) caption for table: ['(*) 해외사업환산손익이 포함되어 있습니다.']
# (p.44) caption for table: ['(*) 해외사업환산손익이 포함되어 있습니다.']
# (p.51) caption for table: []
# (p.52) caption for table: []
# (p.60) caption for table: []
# (p.60) caption for table: []
# (p.61) caption for table: ['(*1) 외화 및 원화 차입금에 대해 통화금리스왑 및 금리스왑을 체결하였으며, 구체적인 내역 은 다음과 같습니다.']
# (p.61) caption for table: []
# (p.61) caption for table: []
# (p.61) caption for table: []
# (p.62) caption for table: ['(*1) 종업원에게 지급하여야 할 연차수당 및 성과상여금 등을 제외한 금액입니다. (*2) 외화 및 원화 차입금에 대해 통화금리스왑 및 금리스왑을 체결하였으며, 구체적인 내역 은 다음과 같습니다.']
# (p.62) caption for table: []
# (p.62) caption for table: []
# (p.62) caption for table: []
# (p.63) caption for table: []
# (p.63) caption for table: []
# (p.63) caption for table: []
# (p.63) caption for table: []
# (p.64) caption for table: []
# (p.64) caption for table: ['(*) 기타손익은 외화환산손익, 외환차손익, 당기손익-공정가치측정금융자산처분손익이 포함 되어 있습니다.']
# (p.65) caption for table: []
# (p.65) caption for table: []
# (p.66) caption for table: ['(*1) 연결회사는 채권의 최초 인식 시점부터 전체 회수예상기간 동안의 기대신용손실을 계산 하여, 대손충당금을 설정하였습니다. (*2) 당기말과 전기말 현재 특수관계자에 대한 매출채권및기타채권은 각각 83,859,716천원 , 65,741,723천원입니다 (주석 32 참조).']
# (p.66) caption for table: []
# (p.66) caption for table: []
# (p.67) caption for table: []
# (p.67) caption for table: []
# (p.68) caption for table: []
# (p.68) caption for table: []
# (p.69) caption for table: []
# (p.69) caption for table: []
# (p.69) caption for table: []
# (p.70) caption for table: ['(*1) 연결회사는 2012년 중 바이오시밀러 개발 및 상업화를 위하여 미국 Biogen The- rapeutics Inc.과 합작법인인 삼성바이오에피스㈜를 설립하였습니다. 연결회사는 2015년 이 전까지 삼성바이오에피스㈜를 연결회사의 종속기업으로 분류하였으나, Bio-gen Therapeutics Inc.가 보유한 삼성바이오에피스㈜에 대한 잠재적 의결권이 실질적인 권리에 해당되고, 해당 약정에 따른 이사회 구성, 주총결의를 위한 의결정족수 등으로 인하여 관련활 동을 일방적으로 통제할 수 없어 연결회사는 2015년 중 삼성바이오에피스㈜를 종속기업에 서 제외하였습니다. 연결회사와 Biogen Therapeutics I-nc.가 체결한 합작계약에 따라 삼 성바이오에피스㈜와 Biogen Therapeutics Inc. 등의 회사는 지적재산권에 관한 계약 등을 체결하고 있습니다. 한편, Biogen Therapeutics Inc.는 연결회사의 피투자기업인 삼성바이오에피스㈜의 지분을 50%-1주까지 매입할 수 있는 콜옵션을 2018년 6월 29일 행사하였고, 2018년 11월 7일 주 식 매매 거래에 대한 모든 법적 절차를 완료하여 당기말 현재 삼성바이오에피스㈜에 대한 연 결회사의 지분율은 50%+1주입니다. (*2) 2020년 9월, 연결회사와 AstraZeneca는 공동기업인 Archigen Biotech Limited의 연 구개발활동을 중단하기로 결정하였습니다. (*3) 연결회사는 당기 중 바이오 분야 Startup 지분투자를 위해 SVIC54호 신기술사업투자조 합에 출자하였습니다.']
# (p.71) caption for table: ['(*) 피투자회사의 자본변동 및 환율변동 등이 포함되어 있습니다.']
# (p.71) caption for table: ['(*1) 피투자회사의 자본변동 및 환율변동 등이 포함되어 있습니다. (*2) 전기 중 연결회사는 피투자기업에 대한 장부금액이 영("0") 이하로 감소하여 지분법 적 용을 중단하였습니다. 전기 중 인식하지 않은 지분법손실은 1,148,724천원입니다.']
# (p.71) caption for table: ['(*) 삼성바이오에피스㈜의 연결기준 재무정보로 순자산공정가치 조정 전입니다.']
# (p.71) caption for table: ['(*) 삼성바이오에피스㈜의 연결기준 재무정보로 순자산공정가치 조정 전입니다.']
# (p.72) caption for table: ['(*) 삼성바이오에피스㈜의 연결기준 재무정보로 순자산공정가치 조정 전입니다.']
# (p.72) caption for table: ['(*) 삼성바이오에피스㈜의 연결기준 재무정보로 순자산공정가치 조정 전입니다.']
# (p.72) caption for table: ['(*) 지배력 상실시점의 순자산공정가치 조정액과 불균등 유상증자와 관련된 투자차액이 포함 되어 있으며, 상각 효과가 반영되어 있습니다.']
# (p.72) caption for table: ['(*) 지배력 상실시점의 순자산공정가치 조정액과 불균등 유상증자와 관련된 투자차액이 포함 되어 있으며, 상각 효과가 반영되어 있습니다.']
# (p.72) caption for table: []
# (p.73) caption for table: []
# (p.73) caption for table: ['(*) 당기 중 투자부동산 20,247,961천원이 유형자산으로 대체되었습니다.']
# (p.73) caption for table: []
# (p.74) caption for table: []
# (p.74) caption for table: []
# (p.74) caption for table: []
# (p.75) caption for table: []
# (p.76) caption for table: []
# (p.76) caption for table: []
# (p.76) caption for table: ['(*) 일부 무형자산의 회수가능액이 장부금액에 중요하게 미달하여 전기 중 손상차손을 인식 하였습니다.']
# (p.77) caption for table: []
# (p.77) caption for table: []
# (p.77) caption for table: []
# (p.77) caption for table: []
# (p.77) caption for table: []
# (p.78) caption for table: []
# (p.78) caption for table: []
# (p.79) caption for table: ['(*) 당기말과 전기말 현재 특수관계자에 대한 매입채무및기타채무는 각각 234,504,395천원 , 17,038,268천원입니다(주석 32 참조).']
# (p.79) caption for table: []
# (p.79) caption for table: []
# (p.80) caption for table: []
# (p.80) caption for table: ['(*) 당기 및 전기 중 증가된 사용권자산은 각각 7,206,634천원, 13,693,769천원입니다.']
# (p.81) caption for table: []
# (p.81) caption for table: []
# (p.82) caption for table: []
# (p.82) caption for table: ['(*) 종업원에게 지급하여야 할 연차수당 및 성과상여금 등을 포함한 금액입니다.']
# (p.82) caption for table: []
# (p.83) caption for table: []
# (p.83) caption for table: []
# (p.83) caption for table: []
# (p.83) caption for table: []
# (p.83) caption for table: []
# (p.84) caption for table: []
# (p.84) caption for table: []
# (p.84) caption for table: []
# (p.85) caption for table: ['(*) 기타 매출원가에는 비정상조업도손실, 재고자산 평가손실 등이 포함되어 있습니다.']
# (p.85) caption for table: []
# (p.86) caption for table: ['(*) 손익계산서 상의 매출원가 및 판매비와관리비를 합한 금액입니다.']
# (p.86) caption for table: []
# (p.87) caption for table: []
# (p.87) caption for table: []
# (p.87) caption for table: []
# (p.88) caption for table: []
# (p.88) caption for table: []
# (p.88) caption for table: []
# (p.89) caption for table: []
# (p.89) caption for table: []
# (p.90) caption for table: []
# (p.91) caption for table: ['(*) 당기와 전기 중 주식수 변동은 없습니다.']
# (p.91) caption for table: []
# (p.92) caption for table: []
# (p.92) caption for table: []
# (p.92) caption for table: []
# (p.94) caption for table: ["(*) 기업회계기준서 제1024호 '특수관계자 공시'에 따른 특수관계자 범위에 포함되지 않으나 독점규제 및 공정거래법에 따른 동일한 대규모기업집단에 소속된 회사입니다."]
# (p.94) caption for table: []
# (p.95) caption for table: ['(*) ㈜멀티캠퍼스, ㈜호텔신라와의 거래가 포함되어 있습니다.']
# (p.95) caption for table: ['(*) ㈜멀티캠퍼스, ㈜호텔신라와의 거래가 포함되어 있습니다.']
# (p.95) caption for table: []
# (p.96) caption for table: ['(*1) 기타수익은 사외적립자산에서 발생한 운용수익으로, 퇴직급여의 차감항목으로 인식하 였습니다. 당기말 현재 사외적립자산으로 삼성화재해상보험㈜에 44,266백만원(전기말 42,670백만원), 삼성생명보험㈜에 27,654백만원(전기말 23,851백만원) 및 삼성증권㈜에 29,721백만원(전기말 25,772백만원)이 적립되어 있습니다. (*2) 멀티캠퍼스, 호텔신라㈜, ㈜시큐아이와의 거래가 포함되어 있습니다.']
# (p.96) caption for table: []
# (p.97) caption for table: []
# (p.97) caption for table: []
# (p.98) caption for table: []
# (p.98) caption for table: []
# (p.98) caption for table: []
# (p.99) caption for table: []
# (p.100) caption for table: ['(*) 연결회사가 보유하는 현금시재액은 제외하였습니다.']
# (p.101) caption for table: []
# (p.101) caption for table: []
# (p.102) caption for table: ['(*) 통화스왑이 체결된 외화차입금은 환위험에 노출되지 않은것으로 보아 제외하였습니다.']
# (p.102) caption for table: []
# (p.103) caption for table: []
# (p.103) caption for table: []
# (p.104) caption for table: []
# (p.105) caption for table: []
# (p.105) caption for table: []
# (p.106) caption for table: []
# (p.106) caption for table: []
# (p.107) caption for table: []
# (p.107) caption for table: []
# (p.108) caption for table: []
# (p.108) caption for table: []
# (p.108) caption for table: []
# (p.109) caption for table: []
# (p.109) caption for table: []
# (p.109) caption for table: []
# (p.111) caption for table: ['(단위 : 원)']
# (p.112) caption for table: []
# (p.112) caption for table: ['(단위 : 원)']
# (p.113) caption for table: []
# (p.113) caption for table: ['(단위 : 원)']
# (p.113) caption for table: ['(단위 : 원)']
# (p.114) caption for table: []
# (p.114) caption for table: ['※ 위의 재무제표는 주주총회 승인전 별도재무제표입니다. 향후 제11기 정기주주총회에서 재무제표 승인 관련 안건이 부결되거나 수정이 발생한 경우 정정보고서를 통해 그 내용 및 사유 등을 반영할 예정입니다.']
# (p.115) caption for table: []
# (p.121) caption for table: []
# (p.122) caption for table: []
# (p.123) caption for table: []
# (p.129) caption for table: []
# (p.130) caption for table: []
# (p.130) caption for table: ['(*1) 외화 및 원화 차입금에 대해 통화금리스왑 및 금리스왑을 체결하였으며, 구체적인 내역 은 다음과 같습니다.']
# (p.130) caption for table: []
# (p.131) caption for table: []
# (p.131) caption for table: ['(*1) 종업원에게 지급하여야 할 연차수당 및 성과상여금 등을 제외한 금액입니다. (*2) 외화 및 원화 차입금에 대해 통화금리스왑 및 금리스왑을 체결하였으며, 구체적인 내역 은 다음과 같습니다.']
# (p.131) caption for table: []
# (p.131) caption for table: []
# (p.132) caption for table: []
# (p.132) caption for table: []
# (p.133) caption for table: []
# (p.133) caption for table: []
# (p.133) caption for table: ['(*) 기타손익은 외화환산손익, 외환차손익, 당기손익-공정가치측정금융자산처분손익이 포함 되어 있습니다.']
# (p.133) caption for table: []
# (p.134) caption for table: []
# (p.134) caption for table: ['(*1) 회사는 채권의 최초 인식 시점부터 전체 회수예상기간 동안의 기대신용손실을 계산하여 , 대손충당금을 설정하였습니다. (*2) 당기말과 전기말 현재 특수관계자에 대한 매출채권 및 기타채권은 각각 83,875,324천 원, 65,970,950천원입니다(주석 32 참조).']
# (p.135) caption for table: []
# (p.135) caption for table: []
# (p.136) caption for table: []
# (p.136) caption for table: []
# (p.137) caption for table: []
# (p.137) caption for table: []
# (p.137) caption for table: []
# (p.137) caption for table: []
# (p.138) caption for table: []
# (p.138) caption for table: ['(*1) 회사는 전기 중 CDO사업의 안정적 수주 확대 및 해외거점 확대운영을 위해 종속기업을 신규 설립 하였습니다. (*2) 2020년 9월, 회사와 AstraZeneca는 공동기업인 Archigen Biotech Limited의 연구개 발활동을 중단하기로 결정하였습니다. (*3) 회사는 당기 중 바이오 분야 Startup 지분투자를 위해 SVIC54호 신기술사업투자조합에 출자하였습니다.']
# (p.139) caption for table: []
# (p.139) caption for table: ['(*) 전기 중 투자주식의 장부금액과 회수가능액의 차이를 손상차손으로 인식하였습니다.']
# (p.140) caption for table: []
# (p.140) caption for table: ['(*) 당기 중 투자부동산 20,247,961천원이 유형자산으로 대체되었습니다.']
# (p.140) caption for table: []
# (p.141) caption for table: []
# (p.141) caption for table: []
# (p.142) caption for table: []
# (p.142) caption for table: []
# (p.142) caption for table: []
# (p.143) caption for table: []
# (p.143) caption for table: ['(*) 일부 무형자산의 회수가능액이 장부금액에 중요하게 미달하여 전기 중 손상차손을 인식 하였습니다.']
# (p.143) caption for table: []
# (p.144) caption for table: []
# (p.144) caption for table: []
# (p.144) caption for table: []
# (p.145) caption for table: []
# (p.145) caption for table: []
# (p.146) caption for table: ['(*) 당기말과 전기말 현재 특수관계자에 대한 매입채무및기타채무는 각각 235,040,011천원, 17,984,851천원입니다(주석 32 참조).']
# (p.146) caption for table: []
# (p.146) caption for table: []
# (p.147) caption for table: []
# (p.147) caption for table: ['(*) 당기 및 전기 중 증가된 사용권자산은 각각 7,190,581천원, 10,451,363천원입니다.']
# (p.148) caption for table: []
# (p.148) caption for table: []
# (p.149) caption for table: []
# (p.149) caption for table: ['(*) 종업원에게 지급하여야 할 연차수당 및 성과상여금 등을 포함한 금액입니다.']
# (p.150) caption for table: []
# (p.150) caption for table: []
# (p.150) caption for table: []
# (p.151) caption for table: []
# (p.151) caption for table: []
# (p.152) caption for table: []
# (p.152) caption for table: []
# (p.152) caption for table: []
# (p.152) caption for table: []
# (p.153) caption for table: ['(*) 기타 매출원가에는 비정상조업도손실, 재고자산 평가손실 등이 포함되어 있습니다.']
# (p.154) caption for table: []
# (p.155) caption for table: ['(*) 손익계산서 상의 매출원가 및 판매비와관리비를 합한 금액입니다.']
# (p.155) caption for table: []
# (p.156) caption for table: []
# (p.156) caption for table: []
# (p.156) caption for table: []
# (p.157) caption for table: []
# (p.157) caption for table: []
# (p.157) caption for table: []
# (p.158) caption for table: []
# (p.158) caption for table: []
# (p.159) caption for table: []
# (p.159) caption for table: []
# (p.160) caption for table: ['(*) 당기와 전기 중 주식수 변동은 없습니다.']
# (p.161) caption for table: []
# (p.162) caption for table: []
# (p.162) caption for table: []
# (p.163) caption for table: ["(*) 기업회계기준서 제1024호 '특수관계자 공시'에 따른 특수관계자 범위에 포함되지 않으나 독점규제 및 공정거래법에 따른 동일한 대규모기업집단에 소속된 회사입니다."]
# (p.164) caption for table: ['(*) ㈜멀티캠퍼스, ㈜호텔신라와의 거래가 포함되어 있습니다.']
# (p.164) caption for table: []
# (p.165) caption for table: ['(*) ㈜멀티캠퍼스, ㈜호텔신라와의 거래가 포함되어 있습니다.']
# (p.166) caption for table: ['(*1) 기타수익은 사외적립자산에서 발생한 운용수익으로, 퇴직급여의 차감항목으로 인식하 였습니다. 당기말 현재 사외적립자산으로 삼성화재해상보험㈜에 44,266백만원(전기말 42,670백만원), 삼성생명보험㈜에 27,654백만원(전기말 23,851백만원) 및 삼성증권㈜에 29,721백만원(전기말 25,772백만원)이 적립되어 있습니다. (*2) ㈜멀티캠퍼스, ㈜호텔신라, ㈜시큐아이와의 거래가 포함되어 있습니다.']
# (p.167) caption for table: ['(*1) 기타수익은 사외적립자산에서 발생한 운용수익으로, 퇴직급여의 차감항목으로 인식하 였습니다. (*2) ㈜멀티캠퍼스, ㈜호텔신라, 에스코어㈜ 와의 거래가 포함되어 있습니다.']
# (p.168) caption for table: []
# (p.168) caption for table: []
# (p.169) caption for table: []
# (p.169) caption for table: []
# (p.170) caption for table: []
# (p.171) caption for table: ['(*) 회사가 보유하는 현금시재액은 제외하였습니다.']
# (p.172) caption for table: []
# (p.173) caption for table: []
# (p.173) caption for table: ['(*) 통화스왑이 체결된 외화차입금은 환위험에 노출되지 않은것으로 보아 제외하였습니다.']
# (p.174) caption for table: []
# (p.174) caption for table: []
# (p.175) caption for table: []
# (p.175) caption for table: []
# (p.178) caption for table: []
# (p.178) caption for table: []
# (p.179) caption for table: ['※ 제9기(전전기)는 개별재무제표 기준이고, 제10기(전기), 제11기(당기)는 연결재무제표 기준입니다.']
# (p.179) caption for table: ['(단위: 회, %)', '※ 최근 5년간 당사는 배당을 지급한 이력이 없습니다.']
# (p.179) caption for table: ['(기준일 : 2021년 12월 31일 )', '(단위 : 원, 주)']
# (p.180) caption for table: []
# (p.180) caption for table: ['(기준일 : 2021년 12월 31일 )', '(단위 : 백만원, %)']
# (p.180) caption for table: ['(기준일 : 2021년 12월 31일 )', '(단위 : 백만원)']
# (p.180) caption for table: ['(기준일 : 2021년 12월 31일 )', '(단위 : 백만원)']
# (p.181) caption for table: ['(기준일 : 2021년 12월 31일 )', '(단위 : 백만원)']
# (p.181) caption for table: ['(기준일 : 2021년 12월 31일 )', '(단위 : 백만원)']
# (p.181) caption for table: ['(기준일 : 2021년 12월 31일 )', '(단위 : 백만원)']
# (p.181) caption for table: ['(작성기준일 : 2021년 12월 31일 )', '(단위 : 백만원, %)']
# (p.181) caption for table: ['(이행현황기준일 : 2021년 12월 31일 )']
# (p.182) caption for table: ['※ 이행현황기준일은 이행현황 판단 시 적용한 회계감사인의 감사의견(확인 및 의견 표시 )이 표명된 가장 최근의 재무제표의 작성기준일이며, 지배구조변경 제한현황 은 공시서류 작성기준일임']
# (p.182) caption for table: ['(기준일 : 2021년 12월 31일 )', '(단위 : 백만원)']
# (p.182) caption for table: ['(기준일 : 2021년 12월 31일 )', '(단위 : 백만원)']
# (p.182) caption for table: ['(기준일 : 2021년 12월 31일 )', '(단위 : 백만원)']
# (p.183) caption for table: []
# (p.184) caption for table: ['(단위 : 백만원,%)']
# (p.185) caption for table: ['(단위 : 백만원)', '※ 한국채택국제회계기준에 따라 작성되었습니다.(연결 기준)']
# (p.185) caption for table: ['(기준일 : 2021년 12월 31일 )', '(단위 : 백만원)', '※ 한국채택국제회계기준에 따라 작성되었습니다.(연결 기준) ※ 매출채권 잔액은 대손충당금 차감 후 금액입니다.']
# (p.185) caption for table: ['(단위: 천원)']
# (p.186) caption for table: ['※ 한국채택국제회계기준에 따라 작성되었습니다.(연결 기준)']
# (p.186) caption for table: []
# (p.186) caption for table: ['(기준일 : 2021년 12월 31일 )', '(단위 : 천원)', '※ 한국채택국제회계기준에 따라 작성되었습니다.(연결 기준)']
# (p.188) caption for table: ['(단위 : 백만원)']
# (p.189) caption for table: ['※ 제11기(당기)는 주주총회 승인전 연결재무제표입니다. 향후 제11기 정기주주총회에서 재무제표 승인 관련 안건이 부결되거나 수정이 발생한 경우 정정보고서를 통해 그 내용 및 사유 등을 반영할 예정입니다.']
# (p.190) caption for table: ['(단위 : 백만원)', '※ 제11기(당기)는 주주총회 승인전 연결재무제표입니다. 향후 제11기 정기주주총회에서 재무제표 승인 관련 안건이 부결되거나 수정이 발생한 경우 정정보고서를 통해 그 내용 및 사유 등을 반영할 예정입니다. ※ 삼성바이오로직스는 단일 사업부문으로 구성되어 있습니다.']
# (p.191) caption for table: ['(*) 통화스왑이 체결된 외화차입금은 환위험에 노출되지 않은것으로 보아 제외하였습니다.']
# (p.191) caption for table: []
# (p.192) caption for table: ['(단위 : 백만원)']
# (p.192) caption for table: []
# (p.193) caption for table: ['※ 사채금액은 사채할인발행차금 1,446백만원을 제외한 실제 상환금액(권면액) 기준입니다.']
# (p.194) caption for table: ['(*) 해당 내용은 차입시점 기준으로 작성되었습니다.']
# (p.194) caption for table: []
# (p.194) caption for table: ['(단위: 원)']
# (p.195) caption for table: ['※ 당기 및 제10기 감사의견은 별도ㆍ연결 재무제표에 대한 감사의견이며, 제9기 감사의견 은 개별 재무제표에 대한 감사의견입니다.']
# (p.195) caption for table: ['[제11기 감사 일정]', '※ 별도ㆍ연결 재무제표 검토 및 감사와 내부회계관리제도 감사에 대한 일정입니다.']
# (p.195) caption for table: ['(단위: 천원, 시간)']
# (p.196) caption for table: []
# (p.196) caption for table: ['(단위: 천원)']
# (p.196) caption for table: ['(단위: 천원, USD)']
# (p.196) caption for table: []
# (p.197) caption for table: []
# (p.198) caption for table: ['[회계감사인의 내부회계관리제도 감사의견]']
# (p.199) caption for table: ['(단위 : 명)']
# (p.199) caption for table: []
# (p.200) caption for table: ["(*1) '21.02.26일(3회차) 1호 안건은 의안 내용 보완 후 재논의하기로 하여 보류하였습니다. 이후 동 안건은 '21.03.19일(5회차)에 재상정하여 가결되었습니다. (*2) 이사회 규정 제7조 제2항에 따라 특별한 이해관계가 있는 구성원은 해당 안건의 결의에 참여하지 않았습니다."]
# (p.201) caption for table: ['※\'21.12.20일(11회차), "특수관계인과의 거래승인의 건" 세부내용 - 대상 : ㈜에스원 - 내용 : 건물관리(미화) - 거래금액 : 187억원 - 기간 : \'22.1 ~ \'22.12']
# (p.201) caption for table: []
# (p.202) caption for table: ['※ 이사회 내 위원회 구성현황은 2021년 12월말 기준입니다. ※ 2021년 2월 26일 경영위원회 구성이 변경되어 김태한 사내이사는 제외되었습니다. ※ 2021년 2월 26일 ESG위원회가 신설되었습니다. 김유니스경희 사외이사가 위원장, 정석우 사외이사, 권순조 사외이사, 허근녕 사외이사가 위원으로 선임되어 위원회를 구성하였습니다. ※ 감사위원회와 사외이사후보 추천위원회는 기업공시서식 작성기준에 따라 제외하였습니다.']
# (p.202) caption for table: []
# (p.203) caption for table: ['※ 2021년 2월 26일 경영위원회 구성이 변경되어 김태한 사내이사는 제외되었습니다.']
# (p.203) caption for table: []
# (p.203) caption for table: []
# (p.204) caption for table: ["※ '21.02.26 의안 주요내용 - 내용 : 삼성 CI 상표 사용계약 체결의 건 - 대상 : 삼성전자 - 금액 : 26,388백만원 ※ '21.07.27 의안 주요내용 - 내용 : 신기술사업투자조합 SVIC 54호 가입의 건 - 목적 : 국내외 바이오 분야 Start-up 기업과의 기술적, 사업적 협력 모색 - 대상 : SVIC 54호 신기술사업투자조합 - 금액 : 49,500백만원 ※ '21.10.26 의안 주요내용 ① 삼우종합건축사사무소 설계용역 계약의 건 - 금액 : 3,200백만원 - 기간 : '21.10월~'22.6월 ② 삼성화재 재산종합보험 가입의 건 - 금액 : 4,210백만원 - 기간 : '21.12월~'22.11월 ※ '21.12.20 의안 주요내용 ① 퇴직연금 불입의 건 - 내용 : 삼성화재, 삼성생명, 삼성증권 2021년말 퇴직연금 추가 불입 - 금액 : 11,260백만원 ② 사내식당 위탁운영 계약의 건 - 내용 : 삼성웰스토리 사내식당 위탁 운영 계약의 건 - 금액 : 14,500백만원 - 기간 : '22.1월~'22.12월"]
# (p.204) caption for table: ['※ 2021년 2월 26일 ESG위원회가 신설되었습니다.']
# (p.205) caption for table: []
# (p.206) caption for table: []
# (p.206) caption for table: ['※ 2021년도에 사외이사후보추천위원회는 개최되지 않았습니다.']
# (p.207) caption for table: ['※ 근속연수는 지원업무 담당 기간 기준입니다.']
# (p.207) caption for table: []
# (p.208) caption for table: []
# (p.208) caption for table: []
# (p.209) caption for table: ['※ 정석우 이사, 권순조 이사는 최초 선임 당시(2016년 8월) 사외이사후보추천위원회가 설 치되지 않은 사유로 이사회에서 추천하였으며, 주주총회에서 선임함']
# (p.209) caption for table: []
# (p.209) caption for table: []
# (p.210) caption for table: ['※ 감사위원회는 상법 제415조의2(감사위원회) 제5항 및 당사 감사위원회 운영규정 7조 1항']
# (p.211) caption for table: []
# (p.211) caption for table: []
# (p.212) caption for table: ['※ 감사위원회와의 커뮤니케이션을 통해 감사위원들의 내부회계 및 사업에 대한 이해도를 제고하고자 격주로 진행업무, 내부회계 관련 동향, 회사 및 제약 산업 현황 등 다양한 정보를 Newsletter 형태로 감사위원들에게 전달하고 있습니다.']
# (p.212) caption for table: ['※ 2019년 10월 1일 감사위원회가 요청하는 업무를 적극 지원하기 위하여 감사위원회 산하조직으로 사내감사팀을 신설하였습니다. ※ 2020년 12월 16일 사내감사팀장이 신규 선임 되었습니다. ※ 2021년 5월 감사위원회 중심의 내부통제 관리감독 업무를 수행하기 위하여 산하에 내부회계평가그룹을 신설하였습니다. ※ 근속연수는 지원업무 담당 기간 기준입니다.']
# (p.212) caption for table: []
# (p.213) caption for table: []
# (p.213) caption for table: []
# (p.213) caption for table: ['(기준일 : 2021년 12월 31일 )']
# (p.214) caption for table: ['(기준일 : 2021년 12월 31일 )', '(단위 : 주)']
# (p.214) caption for table: []
# (p.215) caption for table: ['※ 2019년 9월 16일「주식ㆍ사채 등의 전자등록에 관한 법률」(약칭: "전자증권법") 시행으 로, 주권 및 신주인수권증서에 표시되어야 할 권리가 의무적으로 전자등록됨에 따라 \'주권의 종류\' 구분이 없어졌습니다.']
# (p.215) caption for table: []
# (p.216) caption for table: []
# (p.217) caption for table: ['(기준일 : 2021년 12월 31일 )', '(단위 : 주, %)']
# (p.217) caption for table: ['※ 상기 사항 중 출자자수는 삼성물산㈜의 최근 주주명부 폐쇄일인 2021.12.31일자 기준 보통주 및 우선주 주주수를 합산한 수치이며, 대표이사, 업무집행자, 최대주주 지분율은 공시서류작성기준일인 2021.12.31일자 기준입니다.']
# (p.217) caption for table: []
# (p.218) caption for table: ["※ 2018.3.22일 최치훈, 김신, 김봉영 대표이사가 사임하고, 이영호, 고정석, 정금용 대표이사가 취임하였습니다. ※ 2021.3.19일 이영호, 정금용 대표이사가 사임하고, 오세철, 한승환 대표이사가 취임하였습니다. ※ 공시대상기간 중 주식소유현황의 지분율 변동은 날짜별 성명 및 지분의 변동내역을 전자공시시스템에 별도 공시하므로 삼성물산주식회사의 공시사항 및 '21년 사업보고서를 참고하시기 바랍니다."]
# (p.218) caption for table: ['(단위 : 백만원)', '※ 상기 금액은 2021년말 기준 연결 재무제표 기준입니다.']
# (p.219) caption for table: []
# (p.219) caption for table: []
# (p.219) caption for table: ['※ 최대주주에 대한 보다 자세한 사항은 전자공시시스템(DART)에 공시된 삼성물산주식회사의 2021년 사업보고서를 참조하시기 바랍니다.']
# (p.219) caption for table: ['(기준일 : 2021년 12월 31일 )', '(단위 : 주, %)', '주1) 舊 제일모직이 삼성물산으로 사명을 변경함에 따라 삼성물산이 단독 최대주주로 변경됨. 주2) 현재 최대주주 삼성물산의 소유주식수는 28,742,466주이며, 지분율은 43.44%임.']
# (p.219) caption for table: ['(기준일 : 2021년 12월 31일 )', '(단위 : 주)']
# (p.220) caption for table: ['(기준일 : 2021년 12월 31일 )', '(단위 : 주)']
# (p.220) caption for table: ['(단위 : 원, 주)', "※ 당사는 '16.11.10일자로 유가증권시장에 상장하였습니다."]
# (p.221) caption for table: ['(기준일 : 2021년 12월 31일 )', '(단위 : 주)', "※ 소유주식수는 2021년 12월 31일 기준이며, 이후 변동 현황은 전자공시시스템 (http://dart.fss.or.kr)의 '임원ㆍ주요주주 특정증권 등 소유 상황 보고서'를 참조하시기 바랍니다."]
# (p.221) caption for table: ['(기준일 : 2022년 02월 25일 )']
# (p.222) caption for table: ['※ 보고서 제출일 이후 개최 예정인 제11기 정기주주총회의 안건으로, 향후 정기주주총회에서 부결되거나 수정이 발생한 경우 정정보고서를 통해 그 내용 및 사유 등을 반영할 예정입니다.']
# (p.222) caption for table: ['(기준일 : 2021년 12월 31일 )', '(단위 : 주)']
# (p.223) caption for table: ["※ 2021.12.31일자로 윤광훈 부사장, 이규성 부사장, 안용호 상무, 레지나최 상무가 퇴임하였습니다. ※ 소유주식수는 2021년 12월 31일 기준이며, 이후 변동 현황은 전자공시시스템 (http://dart.fss.or.kr)의 '임원ㆍ주요주주 특정증권 등 소유 상황 보고서'를 참조하시기 바랍니다."]
# (p.224) caption for table: ['※ 2022.02.09 존림 사장의 겸직회사 임기가 만료되었으며, 노균 부사장이 삼성바이오에피스(주)의 기타비상무이사로 선임되었습니다.']
# (p.224) caption for table: []
# (p.224) caption for table: ['(기준일 : 2021년 12월 31일 )', '(단위 : 백만원)', '※ 연간급여총액 및 1인 평균급여액은 소득세법 제20조에 따라 관할 세무서에 제출 하는 근로소득지급명세서의 근로소득공제 반영전 근로소득 기준입니다. ※ 상기 직원의 수는 본사기준이며, 등기임원(7명) 제외 기준입니다. 직원의 수는 휴직자를 포함하여 기재하였습니다. ※ 1인 평균급여액은 연간 평균 재직자 수 3,549명(남: 2,168명, 여: 1,381명) 기준으로 산출하였습니다.']
# (p.224) caption for table: ['(기준일 : 2021년 12월 31일 )', '(단위 : 백만원)']
# (p.225) caption for table: ['(단위 : 백만원)', '※ 주주총회 승인금액은「상법」제388조와 당사 정관에 따라 2021년 3월 19일 정기주주총회 결의를 통해 승인받은 이사의 보수 한도입니다.']
# (p.225) caption for table: ['(단위 : 백만원)', '※ 인원수는 공시서류 작성기준일인 2021.12.31일자 기준입니다.']
# (p.225) caption for table: ['(단위 : 백만원)', '※ 감사위원회 위원 3명은 사외이사 3명으로 구성되어 있습니다. ※ 인원수는 공시서류 작성기준일인 2021.12.31일자 기준입니다.']
# (p.226) caption for table: ['(단위 : 백만원)']
# (p.226) caption for table: ['(단위 : 백만원)']
# (p.227) caption for table: []
# (p.228) caption for table: ['(단위 : 백만원)']
# (p.228) caption for table: ['(단위 : 백만원)']
# (p.229) caption for table: []
# (p.230) caption for table: []
# (p.231) caption for table: ['(기준일 : 2021년 12월 31일 )', '(단위 : 사)', "※상세 현황은 '상세표-2. 계열회사 현황(상세)' 참조"]
# (p.231) caption for table: ['(단위 : %)']
# (p.232) caption for table: ['(단위 : %)']
# (p.232) caption for table: ['(단위 : %)']
# (p.233) caption for table: []
# (p.233) caption for table: ['(단위 : %)']
# (p.233) caption for table: ['(단위 : %)']
# (p.234) caption for table: []
# (p.234) caption for table: ['(단위 : %)']
# (p.235) caption for table: []
# (p.236) caption for table: []
# (p.237) caption for table: []
# (p.238) caption for table: []
# (p.239) caption for table: []
# (p.240) caption for table: []
# (p.241) caption for table: []
# (p.242) caption for table: []
# (p.243) caption for table: []
# (p.244) caption for table: []
# (p.245) caption for table: []
# (p.246) caption for table: []
# (p.247) caption for table: []
# (p.248) caption for table: ['(기준일 : 2021년 12월 31일 )', '(단위 : 백만원)', "※상세 현황은 '상세표-3. 타법인출자 현황(상세)' 참조"]
# (p.248) caption for table: ['※ 2022.02.09 존림 사장의 겸직회사 임기가 만료되었으며, 노균 부사장이 삼성바이오에피스(주)의 기타비상무이사로 선임되었습니다.']
# (p.249) caption for table: ['(단위: 억원)', '※ 최근 사업연도의 매출액의 5/100 이상의 거래입니다.']
# (p.250) caption for table: []
# (p.251) caption for table: []
# (p.252) caption for table: []
# (p.253) caption for table: []
# (p.254) caption for table: []
# (p.254) caption for table: []
# (p.255) caption for table: []
# (p.255) caption for table: []
# (p.256) caption for table: []
# (p.256) caption for table: []
# (p.256) caption for table: []
# (p.258) caption for table: []
# (p.259) caption for table: ['[온실가스 및 에너지]']
# (p.260) caption for table: ['[수자원 관리]']
# (p.260) caption for table: ['[수자원 관리]', '주1) 용수 재이용시설 2017년 12월 신규설치']
# (p.260) caption for table: ['[폐기물 관리]', '[오염물질 관리]']
# (p.260) caption for table: ['[오염물질 관리]', '주1) 수질오염물질: 유기물(COD), 부유물질(SS), 총-질소(T-N), 총-인(T-P)의 합']
# (p.262) caption for table: ['(단위 : 백만원)']
# (p.262) caption for table: ['(기준일 : 2021년 12월 31일 )', '(단위 : 사)']
# (p.263) caption for table: []
# (p.263) caption for table: ['(기준일 : 2021년 12월 31일 )', '(단위 : 백만원, 천주, %)']
# (p.264) caption for table: []
